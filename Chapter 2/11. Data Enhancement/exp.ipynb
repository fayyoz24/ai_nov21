# %%
import pandas as pd

data = pd.read_csv('london_merged.csv')

# %%
data.head()
# Out:
#              timestamp  cnt   t1   t2    hum  wind_speed  weather_code  \
# 0  2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0
# 1  2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0
# 2  2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0
# 3  2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0
# 4  2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0
#
#    is_holiday  is_weekend  season
# 0         0.0         1.0     3.0
# 1         0.0         1.0     3.0
# 2         0.0         1.0     3.0
# 3         0.0         1.0     3.0
# 4         0.0         1.0     3.0

# %%
import pandas as pd
def eda():
    data = pd.read_csv('./london_merged.csv')
    data['year'] = data['timestamp'].apply(lambda row: row[:4])
    data['month'] = data['timestamp'].apply(lambda row: row.split('-')[2][:2] )
    data['hour'] = data['timestamp'].apply(lambda row: row.split(':')[0][-2:] )

    # data.drop('timestamp', axis=1, inplace=True)

    # data['cnt'].describe()
    # data.corr().style.background_gradient(cmap='RdPu')

    #correlations between our target and other features
    corr_target = round(data.corr().iloc[0].sort_values(ascending=False), 3)
    # print(corr_target)

    return data

# %%
import numpy    as np
from numpy.testing._private.utils import decorate_methods
import pandas   as pd
import seaborn  as sb
import matplotlib.pyplot as plt
import sklearn  as skl
import time

from sklearn import pipeline      # Pipeline
from sklearn import preprocessing # OrdinalEncoder, LabelEncoder
from sklearn import impute
from sklearn import compose
from sklearn import model_selection # train_test_split
from sklearn import metrics         # accuracy_score, balanced_accuracy_score, plot_confusion_matrix
from sklearn import set_config


data = eda()

np.random.seed(0)

data['year'] = data['timestamp'].apply(lambda row: row[:4])
data['month'] = data['timestamp'].apply(lambda row: row.split('-')[2][:2] )
data['hour'] = data['timestamp'].apply(lambda row: row.split(':')[0][-2:] )

data.drop('timestamp', axis=1, inplace=True)


def data_enhancement():

    data = eda()
    data['t1_t2'] = data.apply(lambda row: (row['t1']+row['t2'])/2, axis=1)
    # data['hum_win'] = data.apply(lambda row: row['hum']*row['wind_speed'])
    data = data.drop(['t1'], axis=1)
    data = data.drop(['t2'], axis=1)
    
    gen_data = data
    
    return gen_data

# %%
def new_col():

    data = data_enhancement()
   
    y = data['cnt']
    x = data.drop(['cnt'], axis=1)

    cat_vars = ['season','is_weekend','is_holiday','year','month','weather_code']
    num_vars = ['t1_t2','hum','wind_speed'] # multicollinearity problem

    x_train, x_test, y_train, y_test = model_selection.train_test_split(x, y,
                                        test_size=0.2,
                                        random_state=0  # Recommended for reproducibility
                                    )

    transformer = preprocessing.PowerTransformer()
    y_train = transformer.fit_transform(y_train.values.reshape(-1,1))
    y_test = transformer.transform(y_test.values.reshape(-1,1))

    num_4_treeModels = pipeline.Pipeline(steps=[
        ('imputer', impute.SimpleImputer(strategy='constant', fill_value=-9999)),
    ])

    cat_4_treeModels = pipeline.Pipeline(steps=[
        ('imputer', impute.SimpleImputer(strategy='constant', fill_value='missing')),
        ('ordinal', preprocessing.OrdinalEncoder()) # handle_unknown='ignore' ONLY IN VERSION 0.24
    ])

    tree_prepro = compose.ColumnTransformer(transformers=[
        ('num', num_4_treeModels, num_vars),
        ('cat', cat_4_treeModels, cat_vars),
    ], remainder='drop') # Drop other vars not specified in num_vars or cat_vars

    return x_train, x_test, y_train, y_test, tree_prepro

# %%
import numpy    as np
from numpy.testing._private.utils import decorate_methods
import pandas   as pd
import seaborn  as sb
import matplotlib.pyplot as plt
import sklearn  as skl
import time

from sklearn import pipeline      # Pipeline
from sklearn import preprocessing # OrdinalEncoder, LabelEncoder
from sklearn import impute
from sklearn import compose
from sklearn import model_selection # train_test_split
from sklearn import metrics         # accuracy_score, balanced_accuracy_score, plot_confusion_matrix
from sklearn import set_config

from sklearn.tree          import DecisionTreeRegressor
from sklearn.ensemble      import RandomForestRegressor
from sklearn.ensemble      import ExtraTreesRegressor
from sklearn.ensemble      import AdaBoostRegressor
from sklearn.ensemble      import GradientBoostingRegressor
from xgboost               import XGBRegressor
from lightgbm              import LGBMRegressor
from catboost              import CatBoostRegressor


def main():

    x_train, x_test, y_train, y_test, tree_prepro = new_col()

    tree_classifiers = {
  "Decision Tree": DecisionTreeRegressor(),
  "Extra Trees":   ExtraTreesRegressor(n_estimators=100),
  "Random Forest": RandomForestRegressor(n_estimators=100),
  "AdaBoost":      AdaBoostRegressor(n_estimators=100),
  "Skl GBM":       GradientBoostingRegressor(n_estimators=100),
  "XGBoost":       XGBRegressor(n_estimators=100),
  "LightGBM":      LGBMRegressor(n_estimators=100),
  "CatBoost":      CatBoostRegressor(n_estimators=100),
    }
    
    tree_classifiers = {name: pipeline.make_pipeline(tree_prepro, model) for name, model in tree_classifiers.items()}

    rang = abs(y_train.max()) + abs(y_train.min())

    results = pd.DataFrame({'Model': [], 'MSE': [], 'MAB': [], " % error": [], 'Time': []})

    for model_name, model in tree_classifiers.items():
        
        start_time = time.time()
        model.fit(x_train, y_train)
        total_time = time.time() - start_time
            
        pred = model.predict(x_test)
        
        results = results.append({"Model":    model_name,
                                "MSE": metrics.mean_squared_error(y_test, pred),
                                "MAB": metrics.mean_absolute_error(y_test, pred),
                                " % error": metrics.mean_squared_error(y_test, pred) / rang,
                                "Time":     total_time},
                                ignore_index=True)
    return results
main()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\pipeline.py:346: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\pipeline.py:346: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# Learning rate set to 0.403579
# 0:	learn: 0.9063881	total: 5.22ms	remaining: 517ms
# 1:	learn: 0.8506612	total: 10ms	remaining: 491ms
# 2:	learn: 0.8269483	total: 14.7ms	remaining: 475ms
# 3:	learn: 0.8103574	total: 18.9ms	remaining: 453ms
# 4:	learn: 0.8022581	total: 23ms	remaining: 438ms
# 5:	learn: 0.7956701	total: 27.5ms	remaining: 430ms
# 6:	learn: 0.7928462	total: 33.6ms	remaining: 446ms
# 7:	learn: 0.7898856	total: 38.1ms	remaining: 438ms
# 8:	learn: 0.7870869	total: 43.1ms	remaining: 435ms
# 9:	learn: 0.7825252	total: 52.3ms	remaining: 470ms
# 10:	learn: 0.7804358	total: 56.9ms	remaining: 460ms
# 11:	learn: 0.7783388	total: 62.2ms	remaining: 456ms
# 12:	learn: 0.7770159	total: 66.5ms	remaining: 445ms
# 13:	learn: 0.7751194	total: 70.9ms	remaining: 436ms
# 14:	learn: 0.7739744	total: 75.5ms	remaining: 428ms
# 15:	learn: 0.7721130	total: 79.9ms	remaining: 420ms
# 16:	learn: 0.7703520	total: 84.2ms	remaining: 411ms
# 17:	learn: 0.7684088	total: 88.4ms	remaining: 403ms
# 18:	learn: 0.7664659	total: 93.4ms	remaining: 398ms
# 19:	learn: 0.7653650	total: 97.5ms	remaining: 390ms
# 20:	learn: 0.7639414	total: 102ms	remaining: 383ms
# 21:	learn: 0.7633099	total: 106ms	remaining: 375ms
# 22:	learn: 0.7622887	total: 112ms	remaining: 373ms
# 23:	learn: 0.7614127	total: 116ms	remaining: 366ms
# 24:	learn: 0.7602283	total: 120ms	remaining: 359ms
# 25:	learn: 0.7598329	total: 124ms	remaining: 353ms
# 26:	learn: 0.7591262	total: 128ms	remaining: 347ms
# 27:	learn: 0.7587586	total: 132ms	remaining: 340ms
# 28:	learn: 0.7573993	total: 136ms	remaining: 334ms
# 29:	learn: 0.7568554	total: 141ms	remaining: 328ms
# 30:	learn: 0.7553296	total: 145ms	remaining: 323ms
# 31:	learn: 0.7544611	total: 149ms	remaining: 317ms
# 32:	learn: 0.7531751	total: 153ms	remaining: 311ms
# 33:	learn: 0.7519314	total: 158ms	remaining: 307ms
# 34:	learn: 0.7507439	total: 163ms	remaining: 302ms
# 35:	learn: 0.7494372	total: 167ms	remaining: 296ms
# 36:	learn: 0.7493032	total: 171ms	remaining: 292ms
# 37:	learn: 0.7479372	total: 177ms	remaining: 288ms
# 38:	learn: 0.7475966	total: 180ms	remaining: 282ms
# 39:	learn: 0.7463966	total: 186ms	remaining: 278ms
# 40:	learn: 0.7450712	total: 191ms	remaining: 274ms
# 41:	learn: 0.7443024	total: 195ms	remaining: 270ms
# 42:	learn: 0.7432936	total: 201ms	remaining: 267ms
# 43:	learn: 0.7420610	total: 206ms	remaining: 263ms
# 44:	learn: 0.7412398	total: 210ms	remaining: 257ms
# 45:	learn: 0.7399535	total: 215ms	remaining: 252ms
# 46:	learn: 0.7384802	total: 220ms	remaining: 248ms
# 47:	learn: 0.7375734	total: 225ms	remaining: 244ms
# 48:	learn: 0.7363430	total: 230ms	remaining: 239ms
# 49:	learn: 0.7355291	total: 235ms	remaining: 235ms
# 50:	learn: 0.7343347	total: 240ms	remaining: 230ms
# 51:	learn: 0.7336285	total: 244ms	remaining: 226ms
# 52:	learn: 0.7333221	total: 249ms	remaining: 221ms
# 53:	learn: 0.7327958	total: 253ms	remaining: 216ms
# 54:	learn: 0.7315444	total: 257ms	remaining: 211ms
# 55:	learn: 0.7312102	total: 261ms	remaining: 205ms
# 56:	learn: 0.7310950	total: 266ms	remaining: 200ms
# 57:	learn: 0.7295714	total: 270ms	remaining: 195ms
# 58:	learn: 0.7294249	total: 274ms	remaining: 190ms
# 59:	learn: 0.7275286	total: 278ms	remaining: 185ms
# 60:	learn: 0.7267794	total: 283ms	remaining: 181ms
# 61:	learn: 0.7260075	total: 288ms	remaining: 176ms
# 62:	learn: 0.7251663	total: 292ms	remaining: 171ms
# 63:	learn: 0.7244607	total: 297ms	remaining: 167ms
# 64:	learn: 0.7238518	total: 301ms	remaining: 162ms
# 65:	learn: 0.7233246	total: 305ms	remaining: 157ms
# 66:	learn: 0.7221799	total: 312ms	remaining: 154ms
# 67:	learn: 0.7214526	total: 316ms	remaining: 149ms
# 68:	learn: 0.7206923	total: 321ms	remaining: 144ms
# 69:	learn: 0.7197918	total: 325ms	remaining: 139ms
# 70:	learn: 0.7192380	total: 330ms	remaining: 135ms
# 71:	learn: 0.7179595	total: 335ms	remaining: 130ms
# 72:	learn: 0.7169632	total: 339ms	remaining: 125ms
# 73:	learn: 0.7163314	total: 344ms	remaining: 121ms
# 74:	learn: 0.7148550	total: 348ms	remaining: 116ms
# 75:	learn: 0.7140695	total: 352ms	remaining: 111ms
# 76:	learn: 0.7136016	total: 357ms	remaining: 107ms
# 77:	learn: 0.7123644	total: 362ms	remaining: 102ms
# 78:	learn: 0.7116317	total: 366ms	remaining: 97.3ms
# 79:	learn: 0.7106704	total: 371ms	remaining: 92.8ms
# 80:	learn: 0.7105182	total: 376ms	remaining: 88.3ms
# 81:	learn: 0.7100749	total: 381ms	remaining: 83.6ms
# 82:	learn: 0.7092946	total: 386ms	remaining: 79.1ms
# 83:	learn: 0.7087640	total: 392ms	remaining: 74.6ms
# 84:	learn: 0.7076723	total: 397ms	remaining: 70ms
# 85:	learn: 0.7070798	total: 401ms	remaining: 65.2ms
# 86:	learn: 0.7062779	total: 410ms	remaining: 61.2ms
# 87:	learn: 0.7057491	total: 415ms	remaining: 56.5ms
# 88:	learn: 0.7050785	total: 420ms	remaining: 51.9ms
# 89:	learn: 0.7043648	total: 425ms	remaining: 47.2ms
# 90:	learn: 0.7035676	total: 429ms	remaining: 42.4ms
# 91:	learn: 0.7030369	total: 434ms	remaining: 37.7ms
# 92:	learn: 0.7022429	total: 438ms	remaining: 33ms
# 93:	learn: 0.7018963	total: 442ms	remaining: 28.2ms
# 94:	learn: 0.7016125	total: 447ms	remaining: 23.5ms
# 95:	learn: 0.7014862	total: 450ms	remaining: 18.8ms
# 96:	learn: 0.7010537	total: 455ms	remaining: 14.1ms
# 97:	learn: 0.7006170	total: 459ms	remaining: 9.36ms
# 98:	learn: 0.7000788	total: 464ms	remaining: 4.68ms
# 99:	learn: 0.6993157	total: 469ms	remaining: 0us
#            Model       MSE       MAB   % error      Time
# 0  Decision Tree  1.000974  0.725698  0.181615  0.154258
# 1    Extra Trees  0.566613  0.544645  0.102805  4.304508
# 2  Random Forest  0.556641  0.555369  0.100996  5.773753
# 3       AdaBoost  0.692954  0.662069  0.125728  0.479224
# 4        Skl GBM  0.623368  0.612744  0.113103  2.054904
# 5        XGBoost  0.590199  0.580939  0.107084  1.167431
# 6       LightGBM  0.582789  0.587469  0.105740  0.308609
# 7       CatBoost  0.590951  0.589399  0.107221  0.702040

# %%
data = eda()

def data_enhancement(data):
    
    gen_data = data
    
    for season in data['season'].unique():
        seasonal_data = gen_data[gen_data['season'] == season]
        hum_std = seasonal_data['hum'].mean()
        wind_speed_std = seasonal_data['wind_speed'].mean()
        t1_std = seasonal_data['t1'].mean()
        t2_std = seasonal_data['t2'].mean()
        
        for i in gen_data[gen_data['season'] == season].index:
            if np.random.randint(2) == 1:
                gen_data['hum'].values[i] += hum_std/10
            else:
                gen_data['hum'].values[i] -= hum_std/10
                
            if np.random.randint(2) == 1:
                gen_data['wind_speed'].values[i] += wind_speed_std/10
            else:
                gen_data['wind_speed'].values[i] -= wind_speed_std/10
                
            if np.random.randint(2) == 1:
                gen_data['t1'].values[i] += t1_std/10
            else:
                gen_data['t1'].values[i] -= t1_std/10
                
            if np.random.randint(2) == 1:
                gen_data['t2'].values[i] += t2_std/10
            else:
                gen_data['t2'].values[i] -= t2_std/10

    return gen_data
def mean():
    y = data['cnt']
    x = data.drop(['cnt'], axis=1)


    cat_vars = ['season','is_weekend','is_holiday','year','month','weather_code']
    num_vars = ['t1','t2','hum','wind_speed']


    x_train, x_test, y_train, y_test = model_selection.train_test_split(x, y,
                                        test_size=0.2,
                                        random_state=0) # Recommended for reproducibility
                                    
    gen = data_enhancement(data)
    extra_sample = gen.sample(gen.shape[0] // 3)
    x_train = pd.concat([x_train, extra_sample.drop(['cnt'], axis=1 ) ])
    y_train = pd.concat([y_train, extra_sample['cnt'] ])


    transformer = preprocessing.PowerTransformer()
    y_train = transformer.fit_transform(y_train.values.reshape(-1,1))
    y_test = transformer.transform(y_test.values.reshape(-1,1))

    num_4_treeModels = pipeline.Pipeline(steps=[
        ('imputer', impute.SimpleImputer(strategy='constant', fill_value=-9999)),
    ])

    cat_4_treeModels = pipeline.Pipeline(steps=[
        ('imputer', impute.SimpleImputer(strategy='constant', fill_value='missing')),
        ('ordinal', preprocessing.OrdinalEncoder()) # handle_unknown='ignore' ONLY IN VERSION 0.24
    ])

    tree_prepro = compose.ColumnTransformer(transformers=[
        ('num', num_4_treeModels, num_vars),
        ('cat', cat_4_treeModels, cat_vars),
    ], remainder='drop') # Drop other vars not specified in num_vars or cat_vars

    return x_train, x_test, y_train, y_test, tree_prepro

# %%
def main():

    x_train, x_test, y_train, y_test, tree_prepro = mean()

    tree_classifiers = {
  "Decision Tree": DecisionTreeRegressor(),
  "Extra Trees":   ExtraTreesRegressor(n_estimators=100),
  "Random Forest": RandomForestRegressor(n_estimators=100),
  "AdaBoost":      AdaBoostRegressor(n_estimators=100),
  "Skl GBM":       GradientBoostingRegressor(n_estimators=100),
  "XGBoost":       XGBRegressor(n_estimators=100),
  "LightGBM":      LGBMRegressor(n_estimators=100),
  "CatBoost":      CatBoostRegressor(n_estimators=100),
    }
    
    tree_classifiers = {name: pipeline.make_pipeline(tree_prepro, model) for name, model in tree_classifiers.items()}

    rang = abs(y_train.max()) + abs(y_train.min())

    results = pd.DataFrame({'Model': [], 'MSE': [], 'MAB': [], " % error": [], 'Time': []})

    for model_name, model in tree_classifiers.items():
        
        start_time = time.time()
        model.fit(x_train, y_train)
        total_time = time.time() - start_time
            
        pred = model.predict(x_test)
        
        results = results.append({"Model":    model_name,
                                "MSE": metrics.mean_squared_error(y_test, pred),
                                "MAB": metrics.mean_absolute_error(y_test, pred),
                                " % error": metrics.mean_squared_error(y_test, pred) / rang,
                                "Time":     total_time},
                                ignore_index=True)
    return results
main()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\pipeline.py:346: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\pipeline.py:346: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# Learning rate set to 0.42641
# 0:	learn: 0.8959402	total: 9.21ms	remaining: 912ms
# 1:	learn: 0.8544429	total: 20.8ms	remaining: 1.02s
# 2:	learn: 0.8305189	total: 29.2ms	remaining: 944ms
# 3:	learn: 0.8161688	total: 36.3ms	remaining: 872ms
# 4:	learn: 0.8085484	total: 42ms	remaining: 798ms
# 5:	learn: 0.8023113	total: 49.7ms	remaining: 779ms
# 6:	learn: 0.7987743	total: 56ms	remaining: 744ms
# 7:	learn: 0.7962099	total: 64.3ms	remaining: 740ms
# 8:	learn: 0.7927090	total: 70.2ms	remaining: 710ms
# 9:	learn: 0.7905620	total: 77.8ms	remaining: 700ms
# 10:	learn: 0.7891601	total: 83.6ms	remaining: 677ms
# 11:	learn: 0.7871446	total: 89ms	remaining: 653ms
# 12:	learn: 0.7854028	total: 97.3ms	remaining: 651ms
# 13:	learn: 0.7833379	total: 103ms	remaining: 634ms
# 14:	learn: 0.7816341	total: 112ms	remaining: 636ms
# 15:	learn: 0.7800866	total: 118ms	remaining: 619ms
# 16:	learn: 0.7794007	total: 126ms	remaining: 615ms
# 17:	learn: 0.7784678	total: 132ms	remaining: 601ms
# 18:	learn: 0.7774372	total: 137ms	remaining: 584ms
# 19:	learn: 0.7761620	total: 145ms	remaining: 580ms
# 20:	learn: 0.7747910	total: 151ms	remaining: 568ms
# 21:	learn: 0.7738961	total: 160ms	remaining: 566ms
# 22:	learn: 0.7725402	total: 166ms	remaining: 557ms
# 23:	learn: 0.7717047	total: 176ms	remaining: 556ms
# 24:	learn: 0.7711314	total: 183ms	remaining: 549ms
# 25:	learn: 0.7701753	total: 194ms	remaining: 551ms
# 26:	learn: 0.7693724	total: 202ms	remaining: 546ms
# 27:	learn: 0.7683999	total: 213ms	remaining: 548ms
# 28:	learn: 0.7675778	total: 227ms	remaining: 556ms
# 29:	learn: 0.7658494	total: 239ms	remaining: 557ms
# 30:	learn: 0.7642761	total: 250ms	remaining: 557ms
# 31:	learn: 0.7629803	total: 263ms	remaining: 559ms
# 32:	learn: 0.7614124	total: 275ms	remaining: 558ms
# 33:	learn: 0.7604619	total: 287ms	remaining: 557ms
# 34:	learn: 0.7597128	total: 294ms	remaining: 546ms
# 35:	learn: 0.7585900	total: 303ms	remaining: 540ms
# 36:	learn: 0.7581119	total: 310ms	remaining: 528ms
# 37:	learn: 0.7573034	total: 322ms	remaining: 526ms
# 38:	learn: 0.7562466	total: 330ms	remaining: 516ms
# 39:	learn: 0.7546617	total: 340ms	remaining: 510ms
# 40:	learn: 0.7538041	total: 347ms	remaining: 499ms
# 41:	learn: 0.7530912	total: 358ms	remaining: 494ms
# 42:	learn: 0.7515856	total: 367ms	remaining: 487ms
# 43:	learn: 0.7509178	total: 376ms	remaining: 479ms
# 44:	learn: 0.7500044	total: 386ms	remaining: 472ms
# 45:	learn: 0.7491749	total: 395ms	remaining: 464ms
# 46:	learn: 0.7482861	total: 405ms	remaining: 457ms
# 47:	learn: 0.7475735	total: 421ms	remaining: 457ms
# 48:	learn: 0.7470723	total: 428ms	remaining: 446ms
# 49:	learn: 0.7463821	total: 437ms	remaining: 437ms
# 50:	learn: 0.7457299	total: 443ms	remaining: 425ms
# 51:	learn: 0.7450242	total: 452ms	remaining: 418ms
# 52:	learn: 0.7442018	total: 458ms	remaining: 406ms
# 53:	learn: 0.7436200	total: 469ms	remaining: 399ms
# 54:	learn: 0.7427726	total: 477ms	remaining: 390ms
# 55:	learn: 0.7420521	total: 485ms	remaining: 381ms
# 56:	learn: 0.7412280	total: 492ms	remaining: 371ms
# 57:	learn: 0.7404153	total: 500ms	remaining: 362ms
# 58:	learn: 0.7396290	total: 508ms	remaining: 353ms
# 59:	learn: 0.7386372	total: 517ms	remaining: 344ms
# 60:	learn: 0.7372393	total: 523ms	remaining: 334ms
# 61:	learn: 0.7365352	total: 531ms	remaining: 326ms
# 62:	learn: 0.7357491	total: 541ms	remaining: 318ms
# 63:	learn: 0.7353710	total: 548ms	remaining: 308ms
# 64:	learn: 0.7349158	total: 556ms	remaining: 299ms
# 65:	learn: 0.7341429	total: 563ms	remaining: 290ms
# 66:	learn: 0.7334086	total: 573ms	remaining: 282ms
# 67:	learn: 0.7325461	total: 580ms	remaining: 273ms
# 68:	learn: 0.7320190	total: 590ms	remaining: 265ms
# 69:	learn: 0.7310718	total: 596ms	remaining: 255ms
# 70:	learn: 0.7300767	total: 604ms	remaining: 247ms
# 71:	learn: 0.7294968	total: 616ms	remaining: 239ms
# 72:	learn: 0.7287532	total: 627ms	remaining: 232ms
# 73:	learn: 0.7281997	total: 633ms	remaining: 222ms
# 74:	learn: 0.7275881	total: 641ms	remaining: 214ms
# 75:	learn: 0.7266140	total: 647ms	remaining: 204ms
# 76:	learn: 0.7259154	total: 654ms	remaining: 195ms
# 77:	learn: 0.7255204	total: 660ms	remaining: 186ms
# 78:	learn: 0.7249347	total: 665ms	remaining: 177ms
# 79:	learn: 0.7244911	total: 672ms	remaining: 168ms
# 80:	learn: 0.7231779	total: 677ms	remaining: 159ms
# 81:	learn: 0.7224889	total: 686ms	remaining: 150ms
# 82:	learn: 0.7221740	total: 691ms	remaining: 141ms
# 83:	learn: 0.7215351	total: 697ms	remaining: 133ms
# 84:	learn: 0.7207802	total: 703ms	remaining: 124ms
# 85:	learn: 0.7201241	total: 709ms	remaining: 115ms
# 86:	learn: 0.7190938	total: 717ms	remaining: 107ms
# 87:	learn: 0.7185783	total: 723ms	remaining: 98.6ms
# 88:	learn: 0.7177238	total: 731ms	remaining: 90.4ms
# 89:	learn: 0.7171514	total: 738ms	remaining: 82ms
# 90:	learn: 0.7161895	total: 744ms	remaining: 73.5ms
# 91:	learn: 0.7155095	total: 752ms	remaining: 65.4ms
# 92:	learn: 0.7147985	total: 759ms	remaining: 57.1ms
# 93:	learn: 0.7142182	total: 769ms	remaining: 49.1ms
# 94:	learn: 0.7136480	total: 776ms	remaining: 40.8ms
# 95:	learn: 0.7126560	total: 785ms	remaining: 32.7ms
# 96:	learn: 0.7116689	total: 792ms	remaining: 24.5ms
# 97:	learn: 0.7107102	total: 800ms	remaining: 16.3ms
# 98:	learn: 0.7103716	total: 806ms	remaining: 8.14ms
# 99:	learn: 0.7099820	total: 814ms	remaining: 0us
#            Model       MSE       MAB   % error      Time
# 0  Decision Tree  0.951126  0.701450  0.172340  0.250999
# 1    Extra Trees  0.542326  0.530034  0.098267  6.881130
# 2  Random Forest  0.538235  0.546057  0.097526  9.371135
# 3       AdaBoost  0.694285  0.663337  0.125802  0.695199
# 4        Skl GBM  0.623868  0.614214  0.113042  2.864668
# 5        XGBoost  0.572888  0.578116  0.103805  1.644849
# 6       LightGBM  0.572599  0.583833  0.103752  0.416423
# 7       CatBoost  0.585487  0.591034  0.106088  1.160964

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler as scaler
from sklearn.decomposition import PCA
from sklearn.preprocessing import PowerTransformer

# %%
def pca_():
    data = eda()
    np.random.seed(0)

    data['year'] = data['timestamp'].apply(lambda row: row[:4])
    data['month'] = data['timestamp'].apply(lambda row: row.split('-')[2][:2] )
    data['hour'] = data['timestamp'].apply(lambda row: row.split(':')[0][-2:] )

    data.drop('timestamp', axis=1, inplace=True)
    y = data['cnt']
    x = data.drop(['cnt'], axis=1)

    pca = PCA(n_components=3)
    x_red_dim = pca.fit_transform(x)

    x_train, x_test, y_train, y_test = train_test_split(x_red_dim, y,
                                        test_size=0.2,
                                        random_state=0)  

    transformer = PowerTransformer()
    y_train = transformer.fit_transform(y_train.values.reshape(-1,1))
    y_test = transformer.transform(y_test.values.reshape(-1,1))

    return x_train, x_test, y_train, y_test

# %%
def main():

    x_train, x_test, y_train, y_test = pca_()

    tree_classifiers = {
  "Decision Tree": DecisionTreeRegressor(),
  "Extra Trees":   ExtraTreesRegressor(n_estimators=100),
  "Random Forest": RandomForestRegressor(n_estimators=100),
  "AdaBoost":      AdaBoostRegressor(n_estimators=100),
  "Skl GBM":       GradientBoostingRegressor(n_estimators=100),
  "XGBoost":       XGBRegressor(n_estimators=100),
  "LightGBM":      LGBMRegressor(n_estimators=100),
  "CatBoost":      CatBoostRegressor(n_estimators=100),
    }
    
    # tree_classifiers = {name: pipeline.make_pipeline(tree_prepro, model) for name, model in tree_classifiers.items()}

    rang = abs(y_train.max()) + abs(y_train.min())

    results = pd.DataFrame({'Model': [], 'MSE': [], 'MAB': [], " % error": [], 'Time': []})

    for model_name, model in tree_classifiers.items():
        
        start_time = time.time()
        model.fit(x_train, y_train)
        total_time = time.time() - start_time
            
        pred = model.predict(x_test)
        
        results = results.append({"Model":    model_name,
                                "MSE": metrics.mean_squared_error(y_test, pred),
                                "MAB": metrics.mean_absolute_error(y_test, pred),
                                " % error": metrics.mean_squared_error(y_test, pred) / rang,
                                "Time":     total_time},
                                ignore_index=True)
    return results
main()
# Out:
# <ipython-input-65-f7346044245e>:25: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(x_train, y_train)
# <ipython-input-65-f7346044245e>:25: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(x_train, y_train)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# Learning rate set to 0.403579
# 0:	learn: 0.8980442	total: 7.73ms	remaining: 766ms
# 1:	learn: 0.8536649	total: 15.7ms	remaining: 772ms
# 2:	learn: 0.8369116	total: 22.1ms	remaining: 714ms
# 3:	learn: 0.8287218	total: 27.3ms	remaining: 655ms
# 4:	learn: 0.8243486	total: 33.3ms	remaining: 634ms
# 5:	learn: 0.8219111	total: 38.7ms	remaining: 606ms
# 6:	learn: 0.8200639	total: 43.7ms	remaining: 580ms
# 7:	learn: 0.8190432	total: 54.1ms	remaining: 622ms
# 8:	learn: 0.8178497	total: 60.2ms	remaining: 609ms
# 9:	learn: 0.8168945	total: 68ms	remaining: 612ms
# 10:	learn: 0.8158675	total: 72.9ms	remaining: 590ms
# 11:	learn: 0.8148374	total: 79.2ms	remaining: 581ms
# 12:	learn: 0.8138711	total: 83.5ms	remaining: 558ms
# 13:	learn: 0.8127710	total: 87.7ms	remaining: 539ms
# 14:	learn: 0.8122630	total: 92.6ms	remaining: 525ms
# 15:	learn: 0.8118789	total: 98.4ms	remaining: 516ms
# 16:	learn: 0.8113141	total: 103ms	remaining: 501ms
# 17:	learn: 0.8109341	total: 107ms	remaining: 487ms
# 18:	learn: 0.8104854	total: 114ms	remaining: 485ms
# 19:	learn: 0.8096303	total: 118ms	remaining: 473ms
# 20:	learn: 0.8089626	total: 122ms	remaining: 460ms
# 21:	learn: 0.8082261	total: 129ms	remaining: 457ms
# 22:	learn: 0.8076196	total: 133ms	remaining: 446ms
# 23:	learn: 0.8071568	total: 137ms	remaining: 435ms
# 24:	learn: 0.8066150	total: 145ms	remaining: 436ms
# 25:	learn: 0.8057823	total: 149ms	remaining: 425ms
# 26:	learn: 0.8049284	total: 154ms	remaining: 416ms
# 27:	learn: 0.8038443	total: 160ms	remaining: 413ms
# 28:	learn: 0.8026252	total: 165ms	remaining: 404ms
# 29:	learn: 0.8019797	total: 170ms	remaining: 397ms
# 30:	learn: 0.8009516	total: 176ms	remaining: 393ms
# 31:	learn: 0.8001980	total: 182ms	remaining: 386ms
# 32:	learn: 0.7991237	total: 186ms	remaining: 378ms
# 33:	learn: 0.7980045	total: 193ms	remaining: 374ms
# 34:	learn: 0.7967251	total: 197ms	remaining: 366ms
# 35:	learn: 0.7959660	total: 202ms	remaining: 359ms
# 36:	learn: 0.7952956	total: 208ms	remaining: 354ms
# 37:	learn: 0.7939035	total: 213ms	remaining: 347ms
# 38:	learn: 0.7931662	total: 217ms	remaining: 339ms
# 39:	learn: 0.7922862	total: 227ms	remaining: 340ms
# 40:	learn: 0.7913272	total: 231ms	remaining: 333ms
# 41:	learn: 0.7901928	total: 238ms	remaining: 328ms
# 42:	learn: 0.7891641	total: 247ms	remaining: 328ms
# 43:	learn: 0.7882581	total: 256ms	remaining: 326ms
# 44:	learn: 0.7876132	total: 263ms	remaining: 321ms
# 45:	learn: 0.7867984	total: 269ms	remaining: 316ms
# 46:	learn: 0.7861689	total: 275ms	remaining: 310ms
# 47:	learn: 0.7851235	total: 280ms	remaining: 303ms
# 48:	learn: 0.7844511	total: 287ms	remaining: 298ms
# 49:	learn: 0.7832823	total: 291ms	remaining: 291ms
# 50:	learn: 0.7818469	total: 295ms	remaining: 284ms
# 51:	learn: 0.7812912	total: 305ms	remaining: 281ms
# 52:	learn: 0.7806413	total: 310ms	remaining: 275ms
# 53:	learn: 0.7796158	total: 319ms	remaining: 272ms
# 54:	learn: 0.7784098	total: 324ms	remaining: 265ms
# 55:	learn: 0.7777357	total: 328ms	remaining: 258ms
# 56:	learn: 0.7771046	total: 338ms	remaining: 255ms
# 57:	learn: 0.7767772	total: 342ms	remaining: 248ms
# 58:	learn: 0.7758879	total: 351ms	remaining: 244ms
# 59:	learn: 0.7752940	total: 362ms	remaining: 241ms
# 60:	learn: 0.7742977	total: 371ms	remaining: 237ms
# 61:	learn: 0.7733705	total: 380ms	remaining: 233ms
# 62:	learn: 0.7726780	total: 386ms	remaining: 226ms
# 63:	learn: 0.7718497	total: 397ms	remaining: 223ms
# 64:	learn: 0.7706976	total: 402ms	remaining: 216ms
# 65:	learn: 0.7700505	total: 408ms	remaining: 210ms
# 66:	learn: 0.7684757	total: 413ms	remaining: 204ms
# 67:	learn: 0.7677136	total: 418ms	remaining: 197ms
# 68:	learn: 0.7667969	total: 424ms	remaining: 190ms
# 69:	learn: 0.7663029	total: 428ms	remaining: 184ms
# 70:	learn: 0.7655552	total: 433ms	remaining: 177ms
# 71:	learn: 0.7649565	total: 438ms	remaining: 170ms
# 72:	learn: 0.7642590	total: 443ms	remaining: 164ms
# 73:	learn: 0.7637225	total: 451ms	remaining: 159ms
# 74:	learn: 0.7628733	total: 459ms	remaining: 153ms
# 75:	learn: 0.7620612	total: 464ms	remaining: 147ms
# 76:	learn: 0.7613660	total: 469ms	remaining: 140ms
# 77:	learn: 0.7602868	total: 476ms	remaining: 134ms
# 78:	learn: 0.7594549	total: 481ms	remaining: 128ms
# 79:	learn: 0.7590431	total: 487ms	remaining: 122ms
# 80:	learn: 0.7586607	total: 492ms	remaining: 115ms
# 81:	learn: 0.7582663	total: 496ms	remaining: 109ms
# 82:	learn: 0.7574580	total: 500ms	remaining: 102ms
# 83:	learn: 0.7568997	total: 507ms	remaining: 96.5ms
# 84:	learn: 0.7563013	total: 511ms	remaining: 90.2ms
# 85:	learn: 0.7557792	total: 515ms	remaining: 83.9ms
# 86:	learn: 0.7550552	total: 523ms	remaining: 78.1ms
# 87:	learn: 0.7542878	total: 529ms	remaining: 72.2ms
# 88:	learn: 0.7536522	total: 536ms	remaining: 66.2ms
# 89:	learn: 0.7529469	total: 541ms	remaining: 60.1ms
# 90:	learn: 0.7522249	total: 545ms	remaining: 53.9ms
# 91:	learn: 0.7518469	total: 551ms	remaining: 47.9ms
# 92:	learn: 0.7513610	total: 556ms	remaining: 41.8ms
# 93:	learn: 0.7508326	total: 560ms	remaining: 35.8ms
# 94:	learn: 0.7502160	total: 566ms	remaining: 29.8ms
# 95:	learn: 0.7496647	total: 571ms	remaining: 23.8ms
# 96:	learn: 0.7489738	total: 577ms	remaining: 17.9ms
# 97:	learn: 0.7482493	total: 583ms	remaining: 11.9ms
# 98:	learn: 0.7478277	total: 589ms	remaining: 5.95ms
# 99:	learn: 0.7472999	total: 593ms	remaining: 0us
#            Model       MSE       MAB   % error      Time
# 0  Decision Tree  1.218573  0.833660  0.221095  0.121069
# 1    Extra Trees  0.665176  0.630812  0.120688  2.802218
# 2  Random Forest  0.644323  0.621851  0.116905  5.506920
# 3       AdaBoost  0.709598  0.676454  0.128748  0.369066
# 4        Skl GBM  0.671385  0.647842  0.121815  1.765698
# 5        XGBoost  0.659533  0.638493  0.119664  1.764719
# 6       LightGBM  0.644024  0.630831  0.116850  0.161974
# 7       CatBoost  0.653337  0.635600  0.118540  0.721887
